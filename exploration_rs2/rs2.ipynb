# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# function for building VGG Block

def build_resnet_block(output, filters, strides):
    # 입력 레이어
    x = output
    
    x = keras.layers.Conv2D(filters, 
                        3, 
                        strides=strides, 
                        padding='same',
                        use_bias=False)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    
    x = keras.layers.Conv2D(filters,
                        3,
                        strides=1,
                        padding='same',
                        use_bias=False)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    
    x = keras.layers.Conv2D(filters,
                            3,
                            strides=1,
                            padding='same',
                            use_bias=False)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    
    return x

# %%
def build_resnet (input_shape=(32,32,3),
              num_classes=10,
                is_50 = False):
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    output = input_layer
    
    output = keras.layers.Conv2D(filters = 64,
                                kernel_size = 7,
                                strides = 2,
                                padding = 'same')(output)
    output = keras.layers.BatchNormalization()(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.MaxPool2D(pool_size = 3,
                                   strides = 2,
                                   padding = 'same')(output)
    
    prev_filters = 64
    for filters in [64] * 3 + [128] * 4 + [256] * 6 + [512] * 3:
        if(filters == prev_filters):
            strides = 2
        else:
            strides = 1
        output = build_resnet_block(output = output, filters = filters, strides = strides)
        prev_filters = filters
    
    output = keras.layers.GlobalAvgPool2D()(output)
    output = keras.layers.Flatten()(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='predictions')(output)
    
    model = keras.Model(
        inputs=input_layer, 
        outputs=output
    )
    return model

# %%
resnet_34 = build_resnet(input_shape=(32, 32,3), is_50=False)
resnet_34.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_353 (Conv2D)         (None, 16, 16, 64)        9472
#
#  batch_normalization_350 (Ba  (None, 16, 16, 64)       256
#  tchNormalization)
#
#  activation_269 (Activation)  (None, 16, 16, 64)       0
#
#  max_pooling2d_12 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_354 (Conv2D)         (None, 4, 4, 64)          36864
#
#  batch_normalization_351 (Ba  (None, 4, 4, 64)         256
#  tchNormalization)
#
#  activation_270 (Activation)  (None, 4, 4, 64)         0
#
#  conv2d_355 (Conv2D)         (None, 4, 4, 64)          36864
#
#  batch_normalization_352 (Ba  (None, 4, 4, 64)         256
#  tchNormalization)
#
#  activation_271 (Activation)  (None, 4, 4, 64)         0
#
#  conv2d_356 (Conv2D)         (None, 2, 2, 64)          36864
#
#  batch_normalization_353 (Ba  (None, 2, 2, 64)         256
#  tchNormalization)
#
#  activation_272 (Activation)  (None, 2, 2, 64)         0
#
#  conv2d_357 (Conv2D)         (None, 2, 2, 64)          36864
#
#  batch_normalization_354 (Ba  (None, 2, 2, 64)         256
#  tchNormalization)
#
#  activation_273 (Activation)  (None, 2, 2, 64)         0
#
#  conv2d_358 (Conv2D)         (None, 1, 1, 64)          36864
#
#  batch_normalization_355 (Ba  (None, 1, 1, 64)         256
#  tchNormalization)
#
#  activation_274 (Activation)  (None, 1, 1, 64)         0
#
#  conv2d_359 (Conv2D)         (None, 1, 1, 64)          36864
#
#  batch_normalization_356 (Ba  (None, 1, 1, 64)         256
#  tchNormalization)
#
#  activation_275 (Activation)  (None, 1, 1, 64)         0
#
#  conv2d_360 (Conv2D)         (None, 1, 1, 128)         73728
#
#  batch_normalization_357 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_276 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_361 (Conv2D)         (None, 1, 1, 128)         147456
#
#  batch_normalization_358 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_277 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_362 (Conv2D)         (None, 1, 1, 128)         147456
#
#  batch_normalization_359 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_278 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_363 (Conv2D)         (None, 1, 1, 128)         147456
#
#  batch_normalization_360 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_279 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_364 (Conv2D)         (None, 1, 1, 128)         147456
#
#  batch_normalization_361 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_280 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_365 (Conv2D)         (None, 1, 1, 128)         147456
#
#  batch_normalization_362 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_281 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_366 (Conv2D)         (None, 1, 1, 128)         147456
#
#  batch_normalization_363 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_282 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_367 (Conv2D)         (None, 1, 1, 128)         147456
#
#  batch_normalization_364 (Ba  (None, 1, 1, 128)        512
#  tchNormalization)
#
#  activation_283 (Activation)  (None, 1, 1, 128)        0
#
#  conv2d_368 (Conv2D)         (None, 1, 1, 256)         294912
#
#  batch_normalization_365 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_284 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_369 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_366 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_285 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_370 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_367 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_286 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_371 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_368 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_287 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_372 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_369 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_288 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_373 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_370 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_289 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_374 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_371 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_290 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_375 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_372 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_291 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_376 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_373 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_292 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_377 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_374 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_293 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_378 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_375 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_294 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_379 (Conv2D)         (None, 1, 1, 256)         589824
#
#  batch_normalization_376 (Ba  (None, 1, 1, 256)        1024
#  tchNormalization)
#
#  activation_295 (Activation)  (None, 1, 1, 256)        0
#
#  conv2d_380 (Conv2D)         (None, 1, 1, 512)         1179648
#
#  batch_normalization_377 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_296 (Activation)  (None, 1, 1, 512)        0
#
#  conv2d_381 (Conv2D)         (None, 1, 1, 512)         2359296
#
#  batch_normalization_378 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_297 (Activation)  (None, 1, 1, 512)        0
#
#  conv2d_382 (Conv2D)         (None, 1, 1, 512)         2359296
#
#  batch_normalization_379 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_298 (Activation)  (None, 1, 1, 512)        0
#
#  conv2d_383 (Conv2D)         (None, 1, 1, 512)         2359296
#
#  batch_normalization_380 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_299 (Activation)  (None, 1, 1, 512)        0
#
#  conv2d_384 (Conv2D)         (None, 1, 1, 512)         2359296
#
#  batch_normalization_381 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_300 (Activation)  (None, 1, 1, 512)        0
#
#  conv2d_385 (Conv2D)         (None, 1, 1, 512)         2359296
#
#  batch_normalization_382 (Ba  (None, 1, 1, 512)        2048
#  tchNormalization)
#
#  activation_301 (Activation)  (None, 1, 1, 512)        0
#
#  global_average_pooling2d_5   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  flatten_5 (Flatten)         (None, 512)               0
#
#  predictions (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 21,131,274
# Trainable params: 21,116,042
# Non-trainable params: 15,232
# _________________________________________________________________
